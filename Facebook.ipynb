# %%
import pandas as pd

# %%
data = pd.read_csv(r'./Facebook.csv',delimiter=';')

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
row_subset1 = data.loc[0:256]
row_subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 252            129600   Photo         3           7             6          5
# 253            129600  Status         2           7             5         12
# 254            129600   Photo         3           7             5          3
# 255            129600   Photo         2           7             4         12
# 256            129600   Photo         1           7             4          6
#
# ...

# %%
row_subset2 = data.loc[256:]
row_subset2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 256            129600  Photo         1           7             4          6
# 257            129600  Photo         1           7             3         13
# 258            129600  Photo         2           7             3          1
# 259            129600  Photo         3           7             2         13
# 260            129600  Photo         2           7             2          7
# ..                ...    ...       ...         ...           ...        ...
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %%
merged_data1 = pd.concat([row_subset1,row_subset2])

# %%
merged_data2 = row_subset1.merge(row_subset2,how='outer')

# %%
merged_data2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 490             85093   Photo         3           1             7         10
# 491             85093   Photo         3           1             7          2
# 492             81370   Photo         2           1             5          8
# 493             81370   Photo         1           1             5          2
# 494             81370   Photo         3           1             4         11
#
# ...

# %%
col_subset1 = data.iloc[:,:5]
col_subset2 = data.iloc[:,4:]

# %%
col_subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday
# 0              139441   Photo         2          12             4
# 1              139441  Status         2          12             3
# 2              139441   Photo         3          12             3
# 3              139441   Photo         2          12             2
# 4              139441   Photo         2          12             2
# ..                ...     ...       ...         ...           ...
# 494             85093   Photo         3           1             7
# 495             85093   Photo         3           1             7
# 496             81370   Photo         2           1             5
# 497             81370   Photo         1           1             5
# 498             81370   Photo         3           1             4
#
# [495 rows x 5 columns]

# %%
col_subset2
# Out:
#      Post Weekday  Post Hour  Paid  Lifetime Post Total Reach  \
# 0               4          3   0.0                       2752
# 1               3         10   0.0                      10460
# 2               3          3   0.0                       2413
# 3               2         10   1.0                      50128
# 4               2          3   0.0                       7244
# ..            ...        ...   ...                        ...
# 494             7         10   0.0                       5400
# 495             7          2   0.0                       4684
# 496             5          8   0.0                       3480
# 497             5          2   0.0                       3778
# 498             4         11   0.0                       4156
#
#      Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                               5091                     178
# 1                              19057                    1457
# ...

# %%
data_merged3 = col_subset1.merge(col_subset2,how='inner')
data_merged3
# Out:
#        Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0                139441  Photo         2          12             4          3
# 1                139441  Photo         2          12             4          5
# 2                139441  Photo         2          12             4         11
# 3                139441  Photo         2          12             4          2
# 4                139441  Photo         2          12             4         11
# ...                 ...    ...       ...         ...           ...        ...
# 35268             81370  Photo         1           1             5         13
# 35269             81370  Photo         1           1             5          4
# 35270             81370  Photo         1           1             5         11
# 35271             81370  Photo         1           1             5          8
# 35272             81370  Photo         1           1             5          2
#
# ...

# %%
data_reshaped = pd.pivot_table(data,index =['Type','Category'], values =['comment'], aggfunc='sum')
data_reshaped
# Out:
#                  comment
# Type   Category
# Link   1              58
#        2               2
#        3               2
# Photo  1            1091
#        2            1064
#        3            1037
# Status 1              13
#        2             377
#        3              11
# Video  1              86
