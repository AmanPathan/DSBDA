# %%
import pandas as pd

# %%
data = pd.read_csv(r'./airquality.csv')

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     high
# 1             2   36.0    118.0   8.0    72      5    2   medium
# 2             3   12.0    149.0  12.6    74      5    3      low
# 3             4   18.0    313.0  11.5    62      5    4   medium
# 4             5    NaN      NaN  14.3    56      5    5      low
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      low
# 149         150    NaN    145.0  13.2    77      9   27      NaN
# 150         151   14.0    191.0  14.3    75      9   28      low
# 151         152   18.0    131.0   8.0    76      9   29      NaN
# 152         153   20.0    223.0  11.5    68      9   30      low
#
# [153 rows x 8 columns]

# %%
data.drop(columns = 'Unnamed: 0',inplace=True)

# %%
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0   41.0    190.0   7.4    67      5    1     high
# 1   36.0    118.0   8.0    72      5    2   medium
# 2   12.0    149.0  12.6    74      5    3      low
# 3   18.0    313.0  11.5    62      5    4   medium
# 4    NaN      NaN  14.3    56      5    5      low

# %%
data.shape
# Out:
# (153, 7)

# %%
data.isnull().sum()
# Out:
# Ozone       37
# Solar.R      7
# Wind         0
# Temp         0
# Month        0
# Day          0
# Humidity    72
# dtype: int64

# %%
data = data.dropna()

# %%
data.describe()
# Out:
#             Ozone     Solar.R      Wind       Temp      Month        Day
# count   56.000000   56.000000  56.00000  56.000000  56.000000  56.000000
# mean    35.517857  186.500000  10.90000  74.517857   6.446429  16.232143
# std     29.037275   92.518892   3.70832  10.104888   1.548250   8.532273
# min      1.000000    8.000000   2.30000  57.000000   5.000000   1.000000
# 25%     15.500000  116.500000   8.00000  66.750000   5.000000   9.750000
# 50%     27.500000  192.000000  10.60000  74.500000   6.000000  16.000000
# 75%     39.500000  259.250000  12.75000  81.250000   8.000000  22.250000
# max    118.000000  334.000000  20.70000  94.000000   9.000000  31.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ozone     56 non-null     float64
#  1   Solar.R   56 non-null     float64
#  2   Wind      56 non-null     float64
#  3   Temp      56 non-null     int64
#  4   Month     56 non-null     int64
#  5   Day       56 non-null     int64
#  6   Humidity  56 non-null     object
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.5+ KB

# %%
data = data.fillna(method='backfill')

# %%
# Data Cleaning

# %%
data['Ozone']=data['Ozone'].fillna(data['Ozone'].mean())

# %%
data['Solar.R']=data['Solar.R'].fillna(data['Solar.R'].mean())

# %%
data['Humidity'] = data['Humidity'].fillna(data['Humidity'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    0
# dtype: int64

# %%
# Creating Data Subsets and Integration

# %%
subset1 = data.iloc[:,[0,3]]
subset1
# Out:
#      Ozone  Temp
# 0     41.0    67
# 1     36.0    72
# 2     12.0    74
# 3     18.0    62
# 6     23.0    65
# 7     19.0    59
# 8      8.0    61
# 11    16.0    69
# 12    11.0    66
# 13    14.0    68
# 14    18.0    58
# 15    14.0    64
# 16    34.0    66
# 17     6.0    57
# 18    30.0    68
# 19    11.0    62
# 20     1.0    59
# 21    11.0    73
# 22     4.0    61
# 23    32.0    61
# 27    23.0    67
# 28    45.0    81
# 29   115.0    79
# 30    37.0    76
# 37    29.0    82
# 39    71.0    90
# 40    39.0    87
# 43    23.0    82
# 46    21.0    77
# 47    37.0    72
# 48    20.0    65
# 49    12.0    73
# 50    13.0    76
# 63    32.0    81
# 70    85.0    89
# 73    27.0    81
# 76    48.0    81
# 80    63.0    85
# 85   108.0    85
# 92    39.0    81
# 100  110.0    90
# 104   28.0    82
# 107   22.0    77
# 112   21.0    77
# 117   73.0    86
# 120  118.0    94
# 122   85.0    94
# 125   73.0    93
# 128   32.0    84
# 133   44.0    81
# 137   13.0    71
# ...

# %%
subset2 = data.iloc[:,[2,3]]
subset2
# Out:
#      Wind  Temp
# 0     7.4    67
# 1     8.0    72
# 2    12.6    74
# 3    11.5    62
# 6     8.6    65
# 7    13.8    59
# 8    20.1    61
# 11    9.7    69
# 12    9.2    66
# 13   10.9    68
# 14   13.2    58
# 15   11.5    64
# 16   12.0    66
# 17   18.4    57
# 18   11.5    68
# 19    9.7    62
# 20    9.7    59
# 21   16.6    73
# 22    9.7    61
# 23   12.0    61
# 27   12.0    67
# 28   14.9    81
# 29    5.7    79
# 30    7.4    76
# 37    9.7    82
# 39   13.8    90
# 40   11.5    87
# 43    8.0    82
# 46   14.9    77
# 47   20.7    72
# 48    9.2    65
# 49   11.5    73
# 50   10.3    76
# 63    9.2    81
# 70    7.4    89
# 73   14.9    81
# 76    6.9    81
# 80   11.5    85
# 85    8.0    85
# 92    6.9    81
# 100   8.0    90
# 104  11.5    82
# 107  10.3    77
# 112  15.5    77
# 117   8.0    86
# 120   2.3    94
# 122   6.3    94
# 125   2.8    93
# 128  15.5    84
# 133  14.9    81
# 137  11.5    71
# 141  10.3    68
# 145  10.3    81
# 148   6.9    70
# ...

# %%
merged_data = pd.merge(subset1,subset2,on='Temp',how='inner')

# %%
merged_data
# Out:
#      Ozone  Temp  Wind
# 0     41.0    67   7.4
# 1     41.0    67  12.0
# 2     23.0    67   7.4
# 3     23.0    67  12.0
# 4     36.0    72   8.0
# ..     ...   ...   ...
# 145   73.0    93   2.8
# 146   32.0    84  15.5
# 147   13.0    71  11.5
# 148   30.0    70   6.9
# 149   14.0    75  14.3
#
# [150 rows x 3 columns]

# %%
# Label Encoding

# %%
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0   41.0    190.0   7.4    67      5    1     high
# 1   36.0    118.0   8.0    72      5    2   medium
# 2   12.0    149.0  12.6    74      5    3      low
# 3   18.0    313.0  11.5    62      5    4   medium
# 6   23.0    299.0   8.6    65      5    7     high

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
data['Humidity'] = label_encoder.fit_transform(data['Humidity'])

# %%
data['Humidity'].unique()
# Out:
# array([1, 3, 2, 0])

# %%
data
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day  Humidity
# 0     41.0    190.0   7.4    67      5    1         1
# 1     36.0    118.0   8.0    72      5    2         3
# 2     12.0    149.0  12.6    74      5    3         2
# 3     18.0    313.0  11.5    62      5    4         3
# 6     23.0    299.0   8.6    65      5    7         1
# 7     19.0     99.0  13.8    59      5    8         2
# 8      8.0     19.0  20.1    61      5    9         3
# 11    16.0    256.0   9.7    69      5   12         2
# 12    11.0    290.0   9.2    66      5   13         1
# 13    14.0    274.0  10.9    68      5   14         2
# 14    18.0     65.0  13.2    58      5   15         3
# 15    14.0    334.0  11.5    64      5   16         2
# 16    34.0    307.0  12.0    66      5   17         2
# 17     6.0     78.0  18.4    57      5   18         1
# 18    30.0    322.0  11.5    68      5   19         3
# 19    11.0     44.0   9.7    62      5   20         2
# ...

# %%
# OneHotEncoding

# %%
df = pd.read_csv(r'./airquality.csv')

# %%
df.drop(columns = 'Unnamed: 0',inplace=True)

# %%
df
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0     41.0    190.0   7.4    67      5    1     high
# 1     36.0    118.0   8.0    72      5    2   medium
# 2     12.0    149.0  12.6    74      5    3      low
# 3     18.0    313.0  11.5    62      5    4   medium
# 4      NaN      NaN  14.3    56      5    5      low
# ..     ...      ...   ...   ...    ...  ...      ...
# 148   30.0    193.0   6.9    70      9   26      low
# 149    NaN    145.0  13.2    77      9   27      NaN
# 150   14.0    191.0  14.3    75      9   28      low
# 151   18.0    131.0   8.0    76      9   29      NaN
# 152   20.0    223.0  11.5    68      9   30      low
#
# [153 rows x 7 columns]

# %%
df['Ozone']=df['Ozone'].fillna(df['Ozone'].mean())
df['Solar.R']=df['Solar.R'].fillna(df['Solar.R'].mean())
df['Humidity'] = df['Humidity'].fillna(df['Humidity'].mode()[0])

# %%
df
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     high
# 1    36.00000  118.000000   8.0    72      5    2   medium
# 2    12.00000  149.000000  12.6    74      5    3      low
# 3    18.00000  313.000000  11.5    62      5    4   medium
# 4    42.12931  185.931507  14.3    56      5    5      low
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26      low
# 149  42.12931  145.000000  13.2    77      9   27      low
# 150  14.00000  191.000000  14.3    75      9   28      low
# 151  18.00000  131.000000   8.0    76      9   29      low
# 152  20.00000  223.000000  11.5    68      9   30      low
#
# [153 rows x 7 columns]

# %%
oneHot_encoded=pd.get_dummies(df,columns=['Humidity'])
oneHot_encoded=oneHot_encoded.astype(int)
oneHot_encoded
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day  Humidity_   Humidity_high  \
# 0       41      190     7    67      5    1           0              1
# 1       36      118     8    72      5    2           0              0
# 2       12      149    12    74      5    3           0              0
# 3       18      313    11    62      5    4           0              0
# 4       42      185    14    56      5    5           0              0
# ..     ...      ...   ...   ...    ...  ...         ...            ...
# 148     30      193     6    70      9   26           0              0
# 149     42      145    13    77      9   27           0              0
# 150     14      191    14    75      9   28           0              0
# 151     18      131     8    76      9   29           0              0
# 152     20      223    11    68      9   30           0              0
#
#      Humidity_low  Humidity_medium
# 0               0                0
# 1               0                1
# ...

# %%
# Model Building

# %%
X = data[['Ozone']]
Y = data[['Temp']]

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25)

# %%
plt.scatter(x_train,y_train,color='green')
plt.ylabel('Temperature')
plt.xlabel('Ozone')
# Out:
# Text(0.5, 0, 'Ozone')

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predicted = model.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='green')
plt.plot(x_test,y_predicted)
plt.ylabel('Temperature')
plt.xlabel('Ozone')
# Out:
# Text(0.5, 0, 'Ozone')

# %%
r_square = model.score(X,Y)
r_square
# Out:
# 0.5179798426389481
