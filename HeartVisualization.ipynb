# %%
import pandas as pd

# %%
data = pd.read_csv(r'./heart.csv')

# %%
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.columns.values
labels = ['age','oldpeak', 'thalachh','trtbps','thall']
sizes = [data['age'].mean(), data['oldpeak'].mean(), data['thalachh'].mean(),data['trtbps'].mean(),data['thall'].mean()]
colors = ['Red','Blue','Green','Yellow','pink']
explode = (0.1,0,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Average data')
# Out:
# Text(0.5, 1.0, 'Average data')

# %%
import numpy as np
import seaborn as sns

# %%
h = data.iloc[1:21, 0]
y_pos = np.arange(len(h))
v = range(1, 21)
plt.bar(y_pos, h, align='center', alpha=0.5)
plt.xticks(y_pos, v)
plt.ylabel('Value')
plt.xlabel("Age")
plt.title('Age Barplot')
plt.show()

# %%
hist = sns.histplot(data=data, x="age")
hist.set(xlabel ="Age", ylabel = "Value", title ='Histogram for Age')
# Out:
# [Text(0.5, 0, 'Age'),
#  Text(0, 0.5, 'Value'),
#  Text(0.5, 1.0, 'Histogram for Age')]

# %%
h = data.iloc[0:16, 0]
v = data.iloc[0:16, 2]
plt.plot(h, label='age', marker='*', linestyle='dotted')
plt.plot(v, label='restecg', marker='o', linestyle='dashed')
plt.ylim(0, 60)
plt.legend()
plt.ylabel("Value Range")
plt.xlabel("Days")
plt.show()

# %%
s=data.iloc[0:,0]
t=data.iloc[0:,3]
plt.scatter(s,t)
plt.title("Age Vs trtbps")
plt.xlabel("Age")
plt.ylabel("trtbps")
plt.show()

# %%
data.boxplot(by='age',column=['trtbps'], grid=False)
plt.show()

# %%
sns.heatmap(data)
# Out:
# <Axes: >

# %%
sns.set(style = "dark")
sns.pairplot(data)
plt.show()
